# %%
import sys
sys.path.append('./..')
import pickle as pkl

# %%
from cs_comp_utils import generate_cs_data_dict as comper
from cs_comp_utils import create_transform_dict
from tune import tune_with_playground_from_file as t

# %%
#config_file = './../cs_comp_config.json'
#config_file = './../mock_device_demo_config.json'
config_file = './../test.json'

# %%
dic = comper(config_file)
# Out:
# 15:35:12.461  {Pygor} [__init__] -- INFO: Creating server
# 15:35:12.469  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters basic.lengthscale
# 15:35:12.471  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters basic.lengthscale
# 15:35:12.472  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters basic.lengthscale
# 15:35:12.479  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters sum.basic.lengthscale
# 15:35:12.480  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters sum.basic.lengthscale
# 15:35:12.482  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters sum.basic.lengthscale
# 15:35:12.483  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters sum.basic.variance
# 15:35:12.491  {indexable} [_add_to_index_operations] -- WARNING: reconstraining parameters sum.basic.lengthscale
# ...

# %%
a = create_transform_dict(dic)
# Out:
# 15:35:24.972  {font_manager} [_findfont_cached] -- DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# 15:35:24.972  {font_manager} [_findfont_cached] -- DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 15:35:24.973  {font_manager} [_findfont_cached] -- DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 15:35:24.973  {font_manager} [_findfont_cached] -- DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 15:35:24.974  {font_manager} [_findfont_cached] -- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>) = 11.335
# 15:35:24.974  {font_manager} [_findfont_cached] -- DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# ...

# %%
print(dic)
print("\n")
print(out)
# Out:
# {'c8': {0.0: [array([ -803.58649379,  -336.60134199, -1221.04393188]), array([-1158.86363977,  -176.04033131, -1175.43390549]), array([-1117.28397763,   -45.91704096, -1226.85294094]), array([ -501.99590962, -1348.15705117,  -653.35493577]), array([-1308.13926193,  -107.56632722,  -726.08619093])], 2000.0: [array([ -960.49137489,  -306.91294388, -1190.31960567]), array([ -209.93820885, -1992.37380281,  -752.31149023]), array([ -717.32901675, -1228.19983776,  -409.10174805]), array([-1233.92527029,  -464.71802364,  -626.94942846]), array([  -56.24839393, -1993.39888069,  -429.88023987])]}, 'c9': {0.0: [array([  -15.59390669, -1982.05518062,  -482.50812538]), array([ -241.89463721,  -723.72249914, -1999.32806931]), array([-1276.02395184,  -707.45968068,  -248.32171582]), array([ -620.73882661, -1214.74701883,  -573.99737751]), array([-1205.38364357,  -780.42369606,  -433.5771286 ])], 2000.0: [array([ -970.1222184 ,  -510.64419312, -1137.7633275 ]), array([ -880.87628886, -1260.18888649
# ...

# %%
trans_dict = {}

# %%
for gate in dic: 
    for vol in dic[gate]:
        if gate in trans_dict: 
            print(trans_dict)
            trans_dict[gate][vol] = "hell"
        else: 
            trans_dict[gate] = {vol: "hell"}
# Out:
# {'c8': {0.0: 'hell'}}
# {'c8': {0.0: 'hell', 2000.0: 'hell'}, 'c9': {0.0: 'hell'}}

# %%
out.T
# Out:
# array([[ -803.58649379, -1158.86363977, -1117.28397763,  -501.99590962,
#         -1308.13926193,   -15.59390669,  -241.89463721, -1276.02395184,
#          -620.73882661, -1205.38364357],
#        [ -336.60134199,  -176.04033131,   -45.91704096, -1348.15705117,
#          -107.56632722, -1982.05518062,  -723.72249914,  -707.45968068,
#         -1214.74701883,  -780.42369606],
#        [-1221.04393188, -1175.43390549, -1226.85294094,  -653.35493577,
#          -726.08619093,  -482.50812538, -1999.32806931,  -248.32171582,
#          -573.99737751,  -433.5771286 ]])

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*out.T)
plt.show()

# %%
a
# Out:
# {'c8': {0.0: array([[1.03117931, 0.        , 0.        ],
#          [0.        , 1.02863353, 0.        ],
#          [0.        , 0.        , 0.51815152]]),
#   2000.0: array([[0.83245597, 0.        , 0.        ],
#          [0.        , 1.04335875, 0.        ],
#          [0.        , 0.        , 1.17900956]])},
#  'c9': {0.0: array([[1.04563527, 0.        , 0.        ],
#          [0.        , 0.69670458, 0.        ],
#          [0.        , 0.        , 1.06215298]]),
#   2000.0: array([[1.08802001, 0.        , 0.        ],
#          [0.        , 0.69648861, 0.        ],
#          [0.        , 0.        , 0.77742575]])}}

# %%
import numpy as np
model_dict = {}


for gate in a: 
    
    model_dict[gate] = {}
    
    for voltage in a[gate].keys(): 
        for i, name in enumerate(np.array(a[gate][voltage])): 
            model_dict[i] =  np.array(a[gate][voltage])[i, i]
        print(np.array(a[gate][voltage]))
    
    
    x = list(a[gate].keys())
    y = np.array(list(a[gate].values()))[:, 0, 0]
    print(y)
# Out:
# [[1.03117931 0.         0.        ]
#  [0.         1.02863353 0.        ]
#  [0.         0.         0.51815152]]
# [[0.83245597 0.         0.        ]
#  [0.         1.04335875 0.        ]
#  [0.         0.         1.17900956]]
# [1.03117931 0.83245597]
# [[1.04563527 0.         0.        ]
#  [0.         0.69670458 0.        ]
#  [0.         0.         1.06215298]]
# [[1.08802001 0.         0.        ]
#  [0.         0.69648861 0.        ]
#  [0.         0.         0.77742575]]
# [1.04563527 1.08802001]
